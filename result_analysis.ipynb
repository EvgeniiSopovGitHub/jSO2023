# %% [markdown]
# # get data

# %%
dataD10A1Lin = []
f_num = 1
file_name = "jso_F" + str(f_num) + "_D10_Atype1_lin.json"
tmp = pd.read_json(file_name)
dataD10A1Lin.append(tmp)

# %%
dataD10A1Lin[0]
# Out:
#    best_found_value                                best_found_solution  \
# 0             300.0  [-55.9383378844, 4.5430590009, 35.3001126222, ...
#
#    best_found_NFES  best_found_generation  \
# 0           163894                   1814
#
#                                        cec2022_stats  \
# 0  [34870.6828385916, 34870.6828385916, 34870.682...
#
#                                          convergence  \
# 0  [7110303830.225099, 1868413247.774738, 1868413...
#
#                                 diversity_population  \
# 0  [None, None, None, None, None, None, None, Non...
#
#                                    diversity_archive
# 0  [None, None, None, None, None, None, None, Non...

# %%
plt.plot(dataD10A1Lin[0]['convergence'][0])

# %%
plt.plot(dataD10A1Lin[0]['diversity_population'][0])

# %%
_,ax = plt.subplots()
ax.plot(dataD10A1Lin[0]['diversity_archive'][0])
ax.set_xlim(0,20000)
plt.show()
